# %%
import tensorflow as tf
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D , Flatten , Dense ,BatchNormalization , Dropout

# %%
classifier = tf.keras.models.Sequential([
    # 87 85
    
    tf.keras.layers.Input(shape=(64, 64, 3)),
    tf.keras.layers.Conv2D(32, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(64, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Conv2D(128, (3, 3), activation='relu'),
    tf.keras.layers.MaxPooling2D(pool_size=(2, 2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(512, activation='relu'),
    tf.keras.layers.Dense(6, activation='softmax') 
])

# %%
classifier.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
train_datagen = tf.keras.preprocessing.image.ImageDataGenerator(
    rescale=1./255,                # Rescale pixel values from [0, 255] to [0, 1]
    shear_range=0.2,               # Apply random shear transformations
    zoom_range=0.2,                # Apply random zoom transformations
    horizontal_flip=True           # Randomly flip images horizontally
)

test_datagen = tf.keras.preprocessing.image.ImageDataGenerator(rescale=1./255)  # Only rescale test/validation data




training_set = train_datagen.flow_from_directory(
    'dataset/train',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical'  
)

test_set = test_datagen.flow_from_directory(
    'dataset/test',
    target_size=(64, 64),
    batch_size=32,
    class_mode='categorical' 
)

history = classifier.fit(
    training_set,
    steps_per_epoch=int(8000/32),      
    epochs=40,
    validation_data=test_set,
    validation_steps=int(2000/32),     
)

import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(len(acc))

plt.plot(epochs, acc, 'r', label='Training accuracy')
plt.plot(epochs, val_acc, 'b', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.legend()

plt.figure()

plt.plot(epochs, loss, 'r', label='Training loss')
plt.plot(epochs, val_loss, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()

plt.show()
# Out:
# Found 14034 images belonging to 6 classes.
# Found 3000 images belonging to 6 classes.
# Epoch 1/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 31s 122ms/step - accuracy: 0.5771 - loss: 1.0589 - val_accuracy: 0.6265 - val_loss: 0.9736
# Epoch 2/40
# 188/250 ━━━━━━━━━━━━━━━━━━━━ 5s 81ms/step - accuracy: 0.6643 - loss: 0.8676
# C:\Users\ncp\anaconda3\Lib\contextlib.py:158: UserWarning: Your input ran out of data; interrupting training. Make sure that your dataset or generator can generate at least `steps_per_epoch * epochs` batches. You may need to use the `.repeat()` function when building your dataset.
#   self.gen.throw(typ, value, traceback)
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.6643 - loss: 0.8654 - val_accuracy: 0.6969 - val_loss: 0.7956
# Epoch 3/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 22s 87ms/step - accuracy: 0.7099 - loss: 0.7824 - val_accuracy: 0.7535 - val_loss: 0.6809
# Epoch 4/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 14s 56ms/step - accuracy: 0.7368 - loss: 0.6964 - val_accuracy: 0.7569 - val_loss: 0.6797
# Epoch 5/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 19s 74ms/step - accuracy: 0.7530 - loss: 0.6688 - val_accuracy: 0.7954 - val_loss: 0.5834
# Epoch 6/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - accuracy: 0.7694 - loss: 0.6369 - val_accuracy: 0.7923 - val_loss: 0.6093
# Epoch 7/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 69ms/step - accuracy: 0.7686 - loss: 0.6209 - val_accuracy: 0.7918 - val_loss: 0.5774
# Epoch 8/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.7827 - loss: 0.6062 - val_accuracy: 0.7726 - val_loss: 0.6647
# Epoch 9/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.7910 - loss: 0.5759 - val_accuracy: 0.7949 - val_loss: 0.5753
# Epoch 10/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8070 - loss: 0.5334 - val_accuracy: 0.8002 - val_loss: 0.5855
# Epoch 11/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.8054 - loss: 0.5452 - val_accuracy: 0.8125 - val_loss: 0.5449
# Epoch 12/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8021 - loss: 0.5350 - val_accuracy: 0.8002 - val_loss: 0.5890
# Epoch 13/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.8102 - loss: 0.5136 - val_accuracy: 0.8236 - val_loss: 0.5156
# Epoch 14/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - accuracy: 0.8128 - loss: 0.5125 - val_accuracy: 0.8091 - val_loss: 0.5265
# Epoch 15/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.8164 - loss: 0.5070 - val_accuracy: 0.8367 - val_loss: 0.4715
# Epoch 16/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - accuracy: 0.8319 - loss: 0.4735 - val_accuracy: 0.8337 - val_loss: 0.5089
# Epoch 17/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.8253 - loss: 0.4853 - val_accuracy: 0.8382 - val_loss: 0.4752
# Epoch 18/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.8420 - loss: 0.4559 - val_accuracy: 0.8573 - val_loss: 0.4188
# Epoch 19/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.8352 - loss: 0.4536 - val_accuracy: 0.8180 - val_loss: 0.5255
# Epoch 20/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - accuracy: 0.8516 - loss: 0.4218 - val_accuracy: 0.7923 - val_loss: 0.5556
# Epoch 21/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.8488 - loss: 0.4150 - val_accuracy: 0.8286 - val_loss: 0.5142
# Epoch 22/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8412 - loss: 0.4306 - val_accuracy: 0.8081 - val_loss: 0.5596
# Epoch 23/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.8553 - loss: 0.4254 - val_accuracy: 0.8463 - val_loss: 0.4466
# Epoch 24/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8553 - loss: 0.4127 - val_accuracy: 0.8622 - val_loss: 0.4193
# Epoch 25/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 18s 71ms/step - accuracy: 0.8558 - loss: 0.3972 - val_accuracy: 0.8311 - val_loss: 0.5006
# Epoch 26/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8581 - loss: 0.4055 - val_accuracy: 0.8396 - val_loss: 0.5355
# Epoch 27/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 65ms/step - accuracy: 0.8527 - loss: 0.4007 - val_accuracy: 0.8392 - val_loss: 0.4716
# Epoch 28/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 11s 46ms/step - accuracy: 0.8662 - loss: 0.3683 - val_accuracy: 0.8435 - val_loss: 0.5360
# Epoch 29/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.8621 - loss: 0.3818 - val_accuracy: 0.8407 - val_loss: 0.4622
# Epoch 30/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8617 - loss: 0.3689 - val_accuracy: 0.8553 - val_loss: 0.4581
# Epoch 31/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 16s 64ms/step - accuracy: 0.8620 - loss: 0.3738 - val_accuracy: 0.8438 - val_loss: 0.4813
# Epoch 32/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 46ms/step - accuracy: 0.8726 - loss: 0.3484 - val_accuracy: 0.8484 - val_loss: 0.4269
# Epoch 33/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.8757 - loss: 0.3467 - val_accuracy: 0.8483 - val_loss: 0.4755
# Epoch 34/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.8706 - loss: 0.3502 - val_accuracy: 0.8455 - val_loss: 0.5065
# Epoch 35/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 66ms/step - accuracy: 0.8758 - loss: 0.3451 - val_accuracy: 0.8392 - val_loss: 0.5187
# Epoch 36/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 47ms/step - accuracy: 0.8802 - loss: 0.3391 - val_accuracy: 0.8425 - val_loss: 0.4795
# Epoch 37/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.8772 - loss: 0.3401 - val_accuracy: 0.8392 - val_loss: 0.5012
# Epoch 38/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 50ms/step - accuracy: 0.8954 - loss: 0.2896 - val_accuracy: 0.8406 - val_loss: 0.4695
# Epoch 39/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 17s 67ms/step - accuracy: 0.8891 - loss: 0.3088 - val_accuracy: 0.8543 - val_loss: 0.4650
# Epoch 40/40
# 250/250 ━━━━━━━━━━━━━━━━━━━━ 12s 48ms/step - accuracy: 0.8910 - loss: 0.3110 - val_accuracy: 0.8494 - val_loss: 0.5502

# %%
import numpy as np
from tensorflow.keras.preprocessing import image


def predict_image(image_path):
    img = image.load_img(image_path, target_size=(64, 64))  # Load and resize the image
    img_array = image.img_to_array(img)  # Convert image to array
    img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
    img_array /= 255.0  # Rescale the image

    prediction = classifier.predict(img_array)  # Predict the class
    if prediction[0] > 0.5:
        print(f"The image at {image_path} is a Shell")
    else:
        print(f"The image at {image_path} is a Pebble")

# Example usage
image_path = 'dataset/predict.jpg'  # Path to the image to be predicted
predict_image(image_path)

# %%
# Example usage
image_path = 'dataset/r.jpg'  # Path to the image to be predicted
predict_image(image_path)
